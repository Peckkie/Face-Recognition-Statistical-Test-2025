# %%
import pandas as pd
file = '/home/yupaporn/CSV_file/UICCA_DiagRadioExp_AzureDb51Case813Image.csv'
df_before = pd.read_csv(file)
df_before
# Out:
#      Unnamed: 0   Case      FileName Views   Label  Width  Height      X1  \
# 0             0  12215   12215_9.jpg   P42  Normal    800     600  219.60
# 1             1  12215   12215_8.jpg   P41  Normal    800     600  227.00
# 2             2  12215   12215_7.jpg   P52  Normal    800     600  290.00
# 3             3  12215   12215_6.jpg   P52  Normal    800     600  289.90
# 4             4  12215   12215_5.jpg   P61  Normal    800     600  236.70
# ..          ...    ...           ...   ...     ...    ...     ...     ...
# 808         808  12150  12150_13.jpg   P42  Normal    800     600  215.10
# 809         809  12150  12150_12.jpg   P42  Normal    800     600  194.69
# 810         810  12150  12150_11.jpg   P52  Normal    800     600  249.10
# 811         811  12150  12150_10.jpg   P52  Normal    800     600  270.70
# 812         812  12150   12150_1.jpg   P51  Normal    800     600  271.30
#
#          Y1      X2  ...        date  \
# 0    113.40  518.50  ...  20/10/2021
# ...

# %%
df_before.columns
# Out:
# Index(['Unnamed: 0', 'Case', 'FileName', 'Views', 'Label', 'Width', 'Height',
#        'X1', 'Y1', 'X2', 'Y2', 'XML_path', 'LabellingBy', 'P ID', 'Site ID',
#        'date', 'originalImage', 'Path Full', 'Class', 'Sub_class_name',
#        'Sub_class', 'Path Crop', 'Path Crop_I7', 'Sub_Class_15AB', 'Views_'],
#       dtype='object')

# %%
df_before
